# %%
import pandas as pd
import numpy as np
df=pd.read_csv(r"https://raw.githubusercontent.com/dsrscientist/DSData/master/loan_prediction.csv")
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
#Identifying the unique 
[{i:df[i].unique()} for i in df.select_dtypes(include='object').columns]
# Out:
# [{'Loan_ID': array(['LP001002', 'LP001003', 'LP001005', 'LP001006', 'LP001008',
#          'LP001011', 'LP001013', 'LP001014', 'LP001018', 'LP001020',
#          'LP001024', 'LP001027', 'LP001028', 'LP001029', 'LP001030',
#          'LP001032', 'LP001034', 'LP001036', 'LP001038', 'LP001041',
#          'LP001043', 'LP001046', 'LP001047', 'LP001050', 'LP001052',
#          'LP001066', 'LP001068', 'LP001073', 'LP001086', 'LP001087',
#          'LP001091', 'LP001095', 'LP001097', 'LP001098', 'LP001100',
#          'LP001106', 'LP001109', 'LP001112', 'LP001114', 'LP001116',
#          'LP001119', 'LP001120', 'LP001123', 'LP001131', 'LP001136',
#          'LP001137', 'LP001138', 'LP001144', 'LP001146', 'LP001151',
#          'LP001155', 'LP001157', 'LP001164', 'LP001179', 'LP001186',
#          'LP001194', 'LP001195', 'LP001197', 'LP001198', 'LP001199',
#          'LP001205', 'LP001206', 'LP001207', 'LP001213', 'LP001222',
# ...

# %%
df.loc[df['Dependents'].isna()==True]
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 102  LP001350    Male     Yes        NaN      Graduate            No
# 104  LP001357    Male     NaN        NaN      Graduate            No
# 120  LP001426    Male     Yes        NaN      Graduate            No
# 226  LP001754    Male     Yes        NaN  Not Graduate           Yes
# 228  LP001760    Male     NaN        NaN      Graduate            No
# 293  LP001945  Female      No        NaN      Graduate            No
# 301  LP001972    Male     Yes        NaN  Not Graduate            No
# 332  LP002100    Male      No        NaN      Graduate            No
# 335  LP002106    Male     Yes        NaN      Graduate           Yes
# 346  LP002130    Male     Yes        NaN  Not Graduate            No
# 355  LP002144  Female      No        NaN      Graduate            No
# 435  LP002393  Female     NaN        NaN      Graduate            No
# 517  LP002682    Male     Yes        NaN  Not Graduate            No
# ...

# %%
# The PErcentage Applicants acccording to the PropertyArea
import matplotlib.pyplot as plt
df.groupby(['Property_Area']).agg({"Loan_Status":'count'}).plot.pie(subplots=True,autopct='%1.1f%%')
plt.legend(loc='lower right')
plt.title("Percentage of the Property Area")
plt.show()

# %%
# Total Loan Status
df['Loan_Status'].value_counts().plot.pie(subplots=True,autopct='%1.1f%%')
plt.title("Ratio of Loan Status")
plt.show()

# %%
#Percentage of Rejected Loans according to the Property_Area
(df.groupby(['Loan_Status']).get_group('N')['Property_Area'].value_counts()/df['Property_Area'].value_counts()).sort_values().plot.bar()
#Compare to the SubUrban property Area belongs to the Urban and Rural are having higher percentage of Rejected Status
# Out:
# <AxesSubplot:>

# %%
Gender_Married=pd.DataFrame([df.groupby(['Gender']).get_group('Male')['Married'].value_counts()/487,
df.groupby(['Gender']).get_group('Female')['Married'].value_counts().sort_values()/111],index=['Male','Female']).T
Gender_Married
# Loan Applicant according to the Gender,72% of the Female Applicants are not Married where as 
# 73.5% of the Male Applicants are Married
# Out:
#         Male    Female
# Yes  0.73306  0.279279
# No   0.26694  0.720721

# %%
Gender_Graduate=pd.concat([df.groupby(['Gender']).get_group('Female').groupby(['Education','Self_Employed'],dropna=False).agg({'ApplicantIncome':'count'}).rename(columns={"ApplicantIncome":'Female'}),
           df.groupby(['Gender']).get_group('Male').groupby(['Education','Self_Employed'],dropna=False).agg({'ApplicantIncome':'count'}).rename(columns={'ApplicantIncome':'Male'})],axis=1)
Gender_Graduate['Total']=Gender_Graduate.sum(axis=1)
Gender_Graduate
# Majority of the Applicants are not Self Employed
# Out:
#                             Female  Male  Total
# Education    Self_Employed
# Graduate     No                 75   306    381
#              Yes                11    50     61
#              NaN                 6    20     26
# Not Graduate No                 14    96    110
#              Yes                 4    13     17
#              NaN                 2     4      6

# %%
df['Dependents']=df['Dependents'].str.replace('3+','3',regex=False)

# %%
df.groupby(['Self_Employed'],dropna=False).agg({'ApplicantIncome':"mean"}).sort_values(by='ApplicantIncome',ascending=False)
# Out:
#                ApplicantIncome
# Self_Employed
# Yes                7380.817073
# NaN                5863.218750
# No                 5049.748000

# %%
df['Income']=df['ApplicantIncome']+df['CoapplicantIncome']
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df['Ratio_Loan_Income']=df['LoanAmount']/df['Income']
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.groupby(['Loan_Status']).agg({'Ratio_Loan_Income':"mean"}).round(3)
# Out:
#              Ratio_Loan_Income
# Loan_Status
# N                        0.025
# Y                        0.023

# %%
df['Ratio_Loan_Income']=df['Ratio_Loan_Income'].fillna(np.mean(df['Ratio_Loan_Income'])).round(3)
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
#Handling Missing Values in Loan Amount Column
df['LoanAmount']=(df['Income']*df['Ratio_Loan_Income']).round(1)
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.loc[df['Loan_Amount_Term'].isna()==True]
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 19   LP001041    Male     Yes          0      Graduate           NaN
# 36   LP001109    Male     Yes          0      Graduate            No
# 44   LP001136    Male     Yes          0  Not Graduate           Yes
# 45   LP001137  Female      No          0      Graduate            No
# 73   LP001250    Male     Yes         3+  Not Graduate            No
# 112  LP001391    Male     Yes          0  Not Graduate            No
# 165  LP001574    Male     Yes          0      Graduate            No
# 197  LP001669  Female      No          0  Not Graduate            No
# 223  LP001749    Male     Yes          0      Graduate            No
# 232  LP001770    Male      No          0  Not Graduate            No
# 335  LP002106    Male     Yes        NaN      Graduate           Yes
# 367  LP002188    Male      No          0      Graduate            No
# 421  LP002357  Female      No          0  Not Graduate            No
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            614 non-null    object
#  3   Dependents         614 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         614 non-null    float64
#  9   Loan_Amount_Term   614 non-null    float64
#  10  Credit_History     614 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
#  13  Income             614 non-null    float64
#  14  Ratio_Loan_Income  614 non-null    float64
# dtypes: float64(6), int64(1), object(8)
# ...

# %%
df['Loan_Amount_Term']=df['Loan_Amount_Term'].fillna(360.0)
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.groupby(['Self_Employed'],dropna=False).agg({'Income':'mean','ApplicantIncome':"mean"})
# Out:
#                     Income  ApplicantIncome
# Self_Employed
# No             6630.737840      5049.748000
# Yes            8882.158537      7380.817073
# NaN            8420.718750      5863.218750

# %%
f=[]
for j in df.loc[df['Self_Employed'].isna()==True,'ApplicantIncome']:
    if j>5000:
        f.append('Yes')
    else:
        f.append('No')
        
f
# Out:
# ['No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'Yes',
#  'Yes',
#  'No',
#  'Yes',
#  'No',
#  'No',
#  'No',
#  'No',
#  'Yes',
#  'No',
#  'No',
#  'Yes',
#  'Yes',
#  'No',
#  'No',
#  'No',
#  'No',
#  'Yes',
#  'Yes',
#  'No',
#  'Yes',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No',
#  'No']

# %%
df.loc[df['Self_Employed'].isna()==True,'Self_Employed']=f

# %%
df['Credit_History']=df['Credit_History'].fillna(1.0)

# %%
df['Dependents']=df['Dependents'].fillna(0)

# %%
df['Married']=df['Married'].fillna('Yes')

# %%
df['Gender']=df['Gender'].fillna('Male')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             614 non-null    object
#  2   Married            614 non-null    object
#  3   Dependents         614 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      614 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         614 non-null    float64
#  9   Loan_Amount_Term   614 non-null    float64
#  10  Credit_History     614 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
#  13  Income             614 non-null    float64
#  14  Ratio_Loan_Income  614 non-null    float64
# dtypes: float64(6), int64(1), object(8)
# ...

# %%
from sklearn.preprocessing import LabelBinarizer,OrdinalEncoder
df['Loan_Status']=LabelBinarizer().fit_transform(df['Loan_Status']) # Yes:1 No:0
df['Gender']=LabelBinarizer().fit_transform(df['Gender']) # Male:1 Female:0
df['Self_Employed']=LabelBinarizer().fit_transform(df['Self_Employed']) #  No: 0 , Yes:1
df['Property_Area']=OrdinalEncoder().fit_transform(df['Property_Area'].to_numpy()[:,np.newaxis]) # Rural:0 SemiUrban:1 Urban:2
df['Education']=LabelBinarizer().fit_transform(df['Education']) # Graduate:0 Non-Graduate:1
df['Married']=LabelBinarizer().fit_transform(df['Married'])# No:0 Yes:1

# %%
df['Dependents']=df['Dependents'].astype('int')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             614 non-null    int32
#  2   Married            614 non-null    int32
#  3   Dependents         614 non-null    int32
#  4   Education          614 non-null    int32
#  5   Self_Employed      614 non-null    int32
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         614 non-null    float64
#  9   Loan_Amount_Term   614 non-null    float64
#  10  Credit_History     614 non-null    float64
#  11  Property_Area      614 non-null    float64
#  12  Loan_Status        614 non-null    int32
#  13  Income             614 non-null    float64
#  14  Ratio_Loan_Income  614 non-null    float64
# dtypes: float64(7), int32(6), int64(1), object(1)
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,classification_report,roc_auc_score
X=df.loc[:,['Gender', 'Married', 'Dependents', 'Education',
       'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
       'Loan_Amount_Term', 'Credit_History', 'Property_Area']]
y=df['Loan_Status']
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=42)
log=LogisticRegression(solver='liblinear')
log.fit(X_train,y_train)
y_pred=log.predict(X_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.7837837837837838

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.42      0.57        65
#            1       0.76      0.98      0.86       120
#
#     accuracy                           0.78       185
#    macro avg       0.84      0.70      0.71       185
# weighted avg       0.82      0.78      0.76       185

# %%
roc_auc_score(y_test,y_pred)
# Roc_auc_score is greater than 50 
# Logistic Regression is a good model
# Out:
# 0.6993589743589743
