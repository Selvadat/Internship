# %%
import pandas as pd
import numpy as np
df=pd.read_csv(r"https://raw.githubusercontent.com/dsrscientist/dataset3/main/weatherAUS.csv",parse_dates=['Date'])
df.sort_values(by='Date')
# Out:
#            Date     Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0    2008-12-01       Albury     13.4     22.9       0.6          NaN
# 3437 2008-12-01   Wollongong      NaN      NaN       NaN          NaN
# 4289 2008-12-01   Wollongong      NaN      NaN       NaN          NaN
# 4290 2008-12-02   Wollongong      NaN      NaN       NaN          NaN
# 1    2008-12-02       Albury      7.4     25.1       0.0          NaN
# ...         ...          ...      ...      ...       ...          ...
# 3435 2017-06-24  Williamtown      9.4     19.3       0.0          NaN
# 8423 2017-06-24        Uluru      7.8     27.0       0.0          NaN
# 3436 2017-06-25  Williamtown      6.8     19.6       0.0          NaN
# 4288 2017-06-25  Williamtown      6.8     19.6       0.0          NaN
# 8424 2017-06-25        Uluru     14.9      NaN       0.0          NaN
#
#       Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8425 entries, 0 to 8424
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           8425 non-null   datetime64[ns]
#  1   Location       8425 non-null   object
#  2   MinTemp        8350 non-null   float64
#  3   MaxTemp        8365 non-null   float64
#  4   Rainfall       8185 non-null   float64
#  5   Evaporation    4913 non-null   float64
#  6   Sunshine       4431 non-null   float64
#  7   WindGustDir    7434 non-null   object
#  8   WindGustSpeed  7434 non-null   float64
#  9   WindDir9am     7596 non-null   object
#  10  WindDir3pm     8117 non-null   object
#  11  WindSpeed9am   8349 non-null   float64
#  12  WindSpeed3pm   8318 non-null   float64
#  13  Humidity9am    8366 non-null   float64
#  14  Humidity3pm    8323 non-null   float64
#  15  Pressure9am    7116 non-null   float64
#  16  Pressure3pm    7113 non-null   float64
# ...

# %%
alb=df.groupby(['Location']).get_group('Albury').loc[:,['Date','Rainfall']]

# %%
df.loc[df['Evaporation'].notna()==True]
# Out:
#            Date      Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 907  2009-03-10  CoffsHarbour     19.8     27.1      24.4          8.6
# 908  2009-03-11  CoffsHarbour     18.7     25.6       6.8          3.8
# 909  2009-03-12  CoffsHarbour     16.5     25.5      16.8          2.8
# 910  2009-03-13  CoffsHarbour     18.5     26.9       0.0          3.2
# 911  2009-03-14  CoffsHarbour     18.2     28.2       0.0          6.8
# ...         ...           ...      ...      ...       ...          ...
# 8381 2012-11-06        Darwin     25.2     34.5       3.0          4.0
# 8382 2012-11-07        Darwin     26.2     33.3       0.0          6.0
# 8383 2012-11-08        Darwin     24.9     32.8      20.4          6.2
# 8384 2012-11-09        Darwin     25.5     33.1       0.0          4.8
# 8385 2012-11-10        Darwin     24.9     34.3       0.0          5.6
#
#       Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  \
# ...

# %% [markdown]
# # Shifitng the TimeSeries Problem to Supervised Learning to Predict the RainFall by LOcation

# %% [markdown]
# # # Creating the dataset of 7 previous days Rainfall
# alb['Rainfall_1d']=alb['Rainfall'].shift(1)
# alb['Rainfall_2d']=alb['Rainfall'].shift(2)
# alb['Rainfall_3d']=alb['Rainfall'].shift(3)
# alb['Rainfall_4d']=alb['Rainfall'].shift(4)
# alb['Rainfall_5d']=alb['Rainfall'].shift(5)
# alb['Rainfall_6d']=alb['Rainfall'].shift(6)
# alb['Rainfall_7d']=alb['Rainfall'].shift(7)
# alb
# # When you see the dataset for the Date'2011-06-21' --> Rainfall column representing the '2011-06-21' rainfall measure
# # Where Rainfall_1d representing '2011-06-20' , Rainfall_2d representing '2011-06-19'

# %%
alb.dropna(inplace=True) # Removing null values in the dataset

# %%
alb
# Out:
#           Date  Rainfall  Rainfall_1d  Rainfall_2d  Rainfall_3d  Rainfall_4d  \
# 7   2008-12-08       0.0          0.0          0.2          1.0          0.0
# 8   2008-12-09       0.0          0.0          0.0          0.2          1.0
# 9   2008-12-10       1.4          0.0          0.0          0.0          0.2
# 10  2008-12-11       0.0          1.4          0.0          0.0          0.0
# 11  2008-12-12       2.2          0.0          1.4          0.0          0.0
# ..         ...       ...          ...          ...          ...          ...
# 902 2011-06-21      10.6          3.6          0.0          0.2          1.0
# 903 2011-06-22       0.6         10.6          3.6          0.0          0.2
# 904 2011-06-23       3.4          0.6         10.6          3.6          0.0
# 905 2011-06-24       0.0          3.4          0.6         10.6          3.6
# 906 2011-06-25       0.4          0.0          3.4          0.6         10.6
#
#      Rainfall_5d  Rainfall_6d  Rainfall_7d
# ...

# %%
from math import sin,pi
days_in_year=365
def encode_day(timestamp):
            return round(abs(sin(pi*timestamp.timetuple().tm_yday/days_in_year)),5)        
def is_weekend(timestamp):
            if timestamp.weekday() > 4:
                return 1
            return 0       
        
# Converting the date into an encoded format using the above formulas

# %%
alb['encode_day']=[encode_day(t) for t in alb['Date']]
alb['is_weekend']=[is_weekend(t) for t in alb['Date']]
alb
# Out:
#           Date  Rainfall  Rainfall_1d  Rainfall_2d  Rainfall_3d  Rainfall_4d  \
# 7   2008-12-08       0.0          0.0          0.2          1.0          0.0
# 8   2008-12-09       0.0          0.0          0.0          0.2          1.0
# 9   2008-12-10       1.4          0.0          0.0          0.0          0.2
# 10  2008-12-11       0.0          1.4          0.0          0.0          0.0
# 11  2008-12-12       2.2          0.0          1.4          0.0          0.0
# ..         ...       ...          ...          ...          ...          ...
# 902 2011-06-21      10.6          3.6          0.0          0.2          1.0
# 903 2011-06-22       0.6         10.6          3.6          0.0          0.2
# 904 2011-06-23       3.4          0.6         10.6          3.6          0.0
# 905 2011-06-24       0.0          3.4          0.6         10.6          3.6
# 906 2011-06-25       0.4          0.0          3.4          0.6         10.6
#
# ...

# %%
tmp_alb=df.groupby(['Location']).get_group('Albury').loc[:,['Date','MinTemp','MaxTemp']].set_index('Date')

# %%
val=[]
for i in alb['Date']:
    j=i-pd.Timedelta('1days')
    l=i-pd.Timedelta('7days')
    val.append(dict(tmp_alb.loc[l:j,:].mean()))

avg_tmp=pd.DataFrame(val)
alb['Avg_MinTmp_7']=avg_tmp['MinTemp'].values
alb['Avg_MaxTmp_7']=avg_tmp['MaxTemp'].values
alb
# Out:
#           Date  Rainfall  Rainfall_1d  Rainfall_2d  Rainfall_3d  Rainfall_4d  \
# 7   2008-12-08       0.0          0.0          0.2          1.0          0.0
# 8   2008-12-09       0.0          0.0          0.0          0.2          1.0
# 9   2008-12-10       1.4          0.0          0.0          0.0          0.2
# 10  2008-12-11       0.0          1.4          0.0          0.0          0.0
# 11  2008-12-12       2.2          0.0          1.4          0.0          0.0
# ..         ...       ...          ...          ...          ...          ...
# 902 2011-06-21      10.6          3.6          0.0          0.2          1.0
# 903 2011-06-22       0.6         10.6          3.6          0.0          0.2
# 904 2011-06-23       3.4          0.6         10.6          3.6          0.0
# 905 2011-06-24       0.0          3.4          0.6         10.6          3.6
# 906 2011-06-25       0.4          0.0          3.4          0.6         10.6
#
# ...

# %%
alb.drop(['Date'],axis=1,inplace=True)

# %%
alb=alb.round(3)

# %%
alb['Avg_MinTmp_7']=alb['Avg_MinTmp_7'].fillna(9.876312)
alb['Avg_MaxTmp_7']=alb['Avg_MaxTmp_7'].fillna(22.726626)

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,r2_score
from sklearn.ensemble import RandomForestRegressor
X=alb.drop(['Rainfall','Avg_MinTmp_7','Avg_MaxTmp_7','Rainfall_7d','Rainfall_6d','Rainfall_5d','Rainfall_4d','Rainfall_3d','Rainfall_2d'],axis=1)
y=alb['Rainfall']
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=42)
reg=RandomForestRegressor()
reg.fit(X_train,y_train)
y_pred=reg.predict(X_test)
print(r2_score(y_test,y_pred))
mean_squared_error(y_test,y_pred)
# Out:
# 0.024883183561368094
# 50.883227049376124

# %%
# Time Series
ts=df.groupby(['Location']).get_group('Albury').loc[:,['Date','Rainfall']].set_index('Date')
ts=ts.resample('1D').sum()
ts
# Out:
#             Rainfall
# Date
# 2008-12-01       0.6
# 2008-12-02       0.0
# 2008-12-03       0.0
# 2008-12-04       0.0
# 2008-12-05       1.0
# ...              ...
# 2011-06-21      10.6
# 2011-06-22       0.6
# 2011-06-23       3.4
# 2011-06-24       0.0
# 2011-06-25       0.4
#
# [937 rows x 1 columns]

# %%
ts.plot(figsize=(10,8))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
from statsmodels.tsa.stattools import adfuller
adfuller_result=adfuller(ts['Rainfall'].values,autolag='AIC')
print('AdfStatistics:',adfuller_result[0])
print('P-values:',adfuller_result[1])
# Note the P-value is less than 0.05
# Reject the Null Hypothesis Means The time series data is Stationary
# Out:
# AdfStatistics: -10.658347565136555
# P-values: 4.473565010220044e-19

# %%
# TimeSeries Model using Fbprophet
fb=ts.reset_index()
fb.columns=['ds','y']
from fbprophet import Prophet
model=Prophet(daily_seasonality=True)
model.fit(fb)
future=model.make_future_dataframe(periods=30)
forecast=model.predict(future)
forecast.tail(30)
# Out:
#             ds     trend  yhat_lower  yhat_upper  trend_lower  trend_upper  \
# 937 2011-06-26  2.497308   -4.771721   11.743622     2.497308     2.497308
# 938 2011-06-27  2.496534   -5.713323   11.231960     2.496534     2.496534
# 939 2011-06-28  2.495761   -6.621774   10.092331     2.495761     2.495761
# 940 2011-06-29  2.494988   -6.329248   10.319891     2.494988     2.494988
# 941 2011-06-30  2.494214   -6.092294   11.145942     2.494214     2.494214
# 942 2011-07-01  2.493441   -4.702975   12.523853     2.493441     2.493441
# 943 2011-07-02  2.492668   -3.761524   12.889287     2.492668     2.492668
# 944 2011-07-03  2.491894   -3.290498   12.758476     2.491894     2.491894
# 945 2011-07-04  2.491121   -5.156372   11.324246     2.491121     2.491155
# 946 2011-07-05  2.490347   -6.119785   10.792321     2.490313     2.490449
# 947 2011-07-06  2.489574   -5.862482   11.013227     2.489496     2.489770
# ...

# %% [markdown]
# Create a Model to Predict whether Rainfall is there or not for tomorrow

# %%
df
# Out:
#            Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0    2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1    2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2    2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3    2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4    2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
# ...         ...      ...      ...      ...       ...          ...       ...
# 8420 2017-06-21    Uluru      2.8     23.4       0.0          NaN       NaN
# 8421 2017-06-22    Uluru      3.6     25.3       0.0          NaN       NaN
# 8422 2017-06-23    Uluru      5.4     26.9       0.0          NaN       NaN
# 8423 2017-06-24    Uluru      7.8     27.0       0.0          NaN       NaN
# 8424 2017-06-25    Uluru     14.9      NaN       0.0          NaN       NaN
#
# ...

# %%
from sklearn.preprocessing import OneHotEncoder,OrdinalEncoder,LabelBinarizer
df['Location']=OrdinalEncoder().fit_transform(df['Location'].to_numpy()[:,np.newaxis])
df['MinTemp']=df['MinTemp'].fillna(df['MinTemp'].mean())
df['MaxTemp']=df['MaxTemp'].fillna(df['MaxTemp'].mean())
df
# Out:
#            Date  Location  MinTemp    MaxTemp  Rainfall  Evaporation  \
# 0    2008-12-01       1.0     13.4  22.900000       0.6          NaN
# 1    2008-12-02       1.0      7.4  25.100000       0.0          NaN
# 2    2008-12-03       1.0     12.9  25.700000       0.0          NaN
# 3    2008-12-04       1.0      9.2  28.000000       0.0          NaN
# 4    2008-12-05       1.0     17.5  32.300000       1.0          NaN
# ...         ...       ...      ...        ...       ...          ...
# 8420 2017-06-21       9.0      2.8  23.400000       0.0          NaN
# 8421 2017-06-22       9.0      3.6  25.300000       0.0          NaN
# 8422 2017-06-23       9.0      5.4  26.900000       0.0          NaN
# 8423 2017-06-24       9.0      7.8  27.000000       0.0          NaN
# 8424 2017-06-25       9.0     14.9  23.859976       0.0          NaN
#
#       Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  \
# ...

# %%
df['Rainfall']=df['Rainfall'].fillna(0)

# %%
df['RainToday']=df['RainToday'].fillna('No')

# %%
df['RainTomorrow']=df['RainTomorrow'].fillna('No')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8425 entries, 0 to 8424
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           8425 non-null   datetime64[ns]
#  1   Location       8425 non-null   float64
#  2   MinTemp        8425 non-null   float64
#  3   MaxTemp        8425 non-null   float64
#  4   Rainfall       8425 non-null   float64
#  5   Evaporation    4913 non-null   float64
#  6   Sunshine       4431 non-null   float64
#  7   WindGustDir    7434 non-null   object
#  8   WindGustSpeed  7434 non-null   float64
#  9   WindDir9am     7596 non-null   object
#  10  WindDir3pm     8117 non-null   object
#  11  WindSpeed9am   8349 non-null   float64
#  12  WindSpeed3pm   8318 non-null   float64
#  13  Humidity9am    8366 non-null   float64
#  14  Humidity3pm    8323 non-null   float64
#  15  Pressure9am    7116 non-null   float64
#  16  Pressure3pm    7113 non-null   float64
# ...

# %%
df['WindGustSpeed']=df['WindGustSpeed'].fillna(df['WindGustSpeed'].mean())
df['WindSpeed9am']=df['WindSpeed9am'].fillna(df['WindSpeed9am'].mean())
df['WindSpeed3pm']=df['WindSpeed3pm'].fillna(df['WindSpeed3pm'].mean())
df['Humidity9am']=df['Humidity9am'].fillna(df['Humidity9am'].mean())
df['Humidity3pm']=df['Humidity3pm'].fillna(df['Humidity3pm'].mean())
df['Pressure9am']=df['Pressure9am'].fillna(df['Pressure9am'].mean())
df['Pressure3pm']=df['Pressure3pm'].fillna(df['Pressure3pm'].mean())
df['Cloud9am']=df['Cloud9am'].fillna(df['Cloud9am'].mean())
df['Cloud3pm']=df['Cloud3pm'].fillna(df['Cloud3pm'].mean())
df['Temp9am']=df['Temp9am'].fillna(df['Temp9am'].mean())
df['Temp3pm']=df['Temp3pm'].fillna(df['Temp3pm'].mean())
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8425 entries, 0 to 8424
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           8425 non-null   datetime64[ns]
#  1   Location       8425 non-null   float64
#  2   MinTemp        8425 non-null   float64
#  3   MaxTemp        8425 non-null   float64
#  4   Rainfall       8425 non-null   float64
#  5   Evaporation    4913 non-null   float64
#  6   Sunshine       4431 non-null   float64
#  7   WindGustDir    7434 non-null   object
#  8   WindGustSpeed  8425 non-null   float64
#  9   WindDir9am     7596 non-null   object
#  10  WindDir3pm     8117 non-null   object
#  11  WindSpeed9am   8425 non-null   float64
#  12  WindSpeed3pm   8425 non-null   float64
#  13  Humidity9am    8425 non-null   float64
#  14  Humidity3pm    8425 non-null   float64
#  15  Pressure9am    8425 non-null   float64
#  16  Pressure3pm    8425 non-null   float64
# ...

# %%
df['RainToday']=LabelBinarizer().fit_transform(df['RainToday'])
df['RainTomorrow']=LabelBinarizer().fit_transform(df['RainTomorrow'])
df
# Out:
#            Date  Location  MinTemp    MaxTemp  Rainfall  Evaporation  \
# 0    2008-12-01       1.0     13.4  22.900000       0.6          NaN
# 1    2008-12-02       1.0      7.4  25.100000       0.0          NaN
# 2    2008-12-03       1.0     12.9  25.700000       0.0          NaN
# 3    2008-12-04       1.0      9.2  28.000000       0.0          NaN
# 4    2008-12-05       1.0     17.5  32.300000       1.0          NaN
# ...         ...       ...      ...        ...       ...          ...
# 8420 2017-06-21       9.0      2.8  23.400000       0.0          NaN
# 8421 2017-06-22       9.0      3.6  25.300000       0.0          NaN
# 8422 2017-06-23       9.0      5.4  26.900000       0.0          NaN
# 8423 2017-06-24       9.0      7.8  27.000000       0.0          NaN
# 8424 2017-06-25       9.0     14.9  23.859976       0.0          NaN
#
#       Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  \
# ...

# %%
df.columns
# Out:
# Index(['Date', 'Location', 'MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation',
#        'Sunshine', 'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
#        'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#        'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
#        'Temp3pm', 'RainToday', 'RainTomorrow'],
#       dtype='object')

# %%
from sklearn.naive_bayes import BernoulliNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score,roc_auc_score,classification_report
X_b=df.loc[:,['Location', 'MinTemp', 'MaxTemp', 'Rainfall','WindGustSpeed','WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
       'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
       'Temp3pm', 'RainToday']]
y_b=df['RainTomorrow']
X_train,X_test,y_train,y_test=train_test_split(X_b,y_b,test_size=0.3,random_state=42)
clf=BernoulliNB()
clf.fit(X_train,y_train)
pred=clf.predict(X_test)
accuracy_score(y_test,pred)
# Out:
# 0.7670094936708861

# %%
roc_auc_score(y_test,pred)
# Out:
# 0.663843910421368

# %%
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.86      0.85      1943
#            1       0.50      0.47      0.48       585
#
#     accuracy                           0.77      2528
#    macro avg       0.67      0.66      0.67      2528
# weighted avg       0.76      0.77      0.76      2528

# %%
clf_1=RandomForestClassifier()
clf_1.fit(X_train,y_train)
pred_1=clf_1.predict(X_test)
accuracy_score(y_test,pred_1)
# Out:
# 0.9003164556962026

# %%
roc_auc_score(y_test,pred_1)
# Out:
# 0.8240415957348536

# %%
print(classification_report(y_test,pred_1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.97      0.94      1943
#            1       0.86      0.68      0.76       585
#
#     accuracy                           0.90      2528
#    macro avg       0.88      0.82      0.85      2528
# weighted avg       0.90      0.90      0.90      2528
